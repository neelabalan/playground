# %%
import pandas as pd
import pathlib
datapath = pathlib.Path('data')
df_list = [pd.read_csv(path) for path in datapath.iterdir()]

# %%
df = df_list[0]
df
# Out:
#      Symbol                                       Company Name
# 0      AAIT  iShares MSCI All Country Asia Information Tech...
# 1       AAL                      American Airlines Group, Inc.
# 2      AAME                      Atlantic American Corporation
# 3      AAOI                      Applied Optoelectronics, Inc.
# 4      AAON                                         AAON, Inc.
# ...     ...                                                ...
# 2962     ZN                                 Zion Oil & Gas Inc
# 2963   ZNGA                                         Zynga Inc.
# 2964   ZSPH                                    ZS Pharma, Inc.
# 2965     ZU                                       zulily, inc.
# 2966   ZUMZ                                        Zumiez Inc.
#
# [2967 rows x 2 columns]

# %%
df_list[0].query('Symbol.str.contains("AA")')
# Out:
#      Symbol                                       Company Name
# 0      AAIT  iShares MSCI All Country Asia Information Tech...
# 1       AAL                      American Airlines Group, Inc.
# 2      AAME                      Atlantic American Corporation
# 3      AAOI                      Applied Optoelectronics, Inc.
# 4      AAON                                         AAON, Inc.
# 5      AAPL                                         Apple Inc.
# 6      AAVL                    Avalanche Biotechnologies, Inc.
# 7      AAWW                       Atlas Air Worldwide Holdings
# 8      AAXJ  iShares MSCI All Country Asia ex Japan Index Fund
# 407    CAAS                     China Automotive Systems, Inc.
# 1755   MPAA                    Motorcar Parts of America, Inc.
# 1985   PAAS                          Pan American Silver Corp.
# 2098   PRAA                                    PRA Group, Inc.
# 2208  RBCAA                             Republic Bancorp, Inc.
# ...

# %%
dtypes= df_list[3].dtypes
df_list[3].astype
df = pd.DataFrame({'column':dtypes.index, 'type':dtypes.values})
df.to_dict('records')
# Out:
# {}

# %%
df
# Out:
#                                      column     type
# 0                                      FIFA   object
# 1                                      Dial   object
# 2                         ISO3166-1-Alpha-3   object
# 3                                      MARC   object
# 4                            is_independent   object
# 5                         ISO3166-1-numeric  float64
# 6                                      GAUL   object
# 7                                      FIPS   object
# 8                                       WMO   object
# 9                         ISO3166-1-Alpha-2   object
# 10                                      ITU   object
# 11                                      IOC   object
# 12                                       DS   object
# 13                    UNTERM Spanish Formal   object
# 14                              Global Code   object
# 15                 Intermediate Region Code  float64
# 16                         official_name_fr   object
# ...
